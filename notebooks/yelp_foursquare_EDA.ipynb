# %%
# imports
import os
import requests
import pandas as pd
import json
from pandas import json_normalize

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
url = "https://api.foursquare.com/v3/places/search?query=bike&ll=55.858167%2C-4.245483&radius=1000"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3MzktfSCg8kREITsopfR8zTnwtbqZhJ09Vx1/q6tXXoA="
}

response1 = requests.get(url, headers=headers)
a = response1.json()
df2 = json_normalize(a['results'])
df2= df2.drop(df2.columns[[0,1,2,4,6,9,10,11,12,13,15,16]], axis=1)
df2
# Out:
#    distance                                               name  \
# 0       416                              Billy Bilsland Cycles
# 1       563  Nextbike 8460 - Glasgow Green - Saltmarket / C...
# 2       645                    Nextbike 8410 - St Enoch Square
# 3       677                                      Glasgow Green
# 4       801                                       Evans Cycles
# 5       846                                 Philip Lang Cycles
#
#    geocodes.main.latitude  geocodes.main.longitude  \
# 0               55.854474                -4.246063
# 1               55.853371                -4.246940
# 2               55.856679                -4.255449
# 3               55.852328                -4.241199
# 4               55.863443                -4.254147
# 5               55.855875                -4.239028
#
#                        location.formatted_address location.postcode  \
# 0   176 Saltmarket, Glasgow, Glasgow City, G1 5LA            G1 5LA
# 1         Clyde St, Glasgow, Glasgow City, G1 5JT            G1 5JT
# 2  St Enoch Square, Glasgow, Glasgow City, G1 4EE            G1 4EE
# 3     Greendyke St, Glasgow, Glasgow City, G1 5DB            G1 5DB
# 4       19 Bath St, Glasgow, Glasgow City, G2 1HY            G2 1HY
# 5   163 Gallowgate, Glasgow, Glasgow City, G1 5ED            G1 5ED
#
#   location.region location.cross_street  \
# 0    Glasgow City                   NaN
# 1    Glasgow City
# 2    Glasgow City
# 3    Glasgow City                   NaN
# 4    Glasgow City
# 5    Glasgow City
#
#                              related_places.children
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'fsq_id': '58d7d7acb50d5211e04dfdf4', 'name'...
# 4                                                NaN
# 5                                                NaN

# %%
df2= df2.drop(df2.columns[[7,8]], axis=1)
df2
# Out:
#    distance                                               name  \
# 0       416                              Billy Bilsland Cycles
# 1       563  Nextbike 8460 - Glasgow Green - Saltmarket / C...
# 2       645                    Nextbike 8410 - St Enoch Square
# 3       677                                      Glasgow Green
# 4       801                                       Evans Cycles
# 5       846                                 Philip Lang Cycles
#
#    geocodes.main.latitude  geocodes.main.longitude  \
# 0               55.854474                -4.246063
# 1               55.853371                -4.246940
# 2               55.856679                -4.255449
# 3               55.852328                -4.241199
# 4               55.863443                -4.254147
# 5               55.855875                -4.239028
#
#                        location.formatted_address location.postcode  \
# 0   176 Saltmarket, Glasgow, Glasgow City, G1 5LA            G1 5LA
# 1         Clyde St, Glasgow, Glasgow City, G1 5JT            G1 5JT
# 2  St Enoch Square, Glasgow, Glasgow City, G1 4EE            G1 4EE
# 3     Greendyke St, Glasgow, Glasgow City, G1 5DB            G1 5DB
# 4       19 Bath St, Glasgow, Glasgow City, G2 1HY            G2 1HY
# 5   163 Gallowgate, Glasgow, Glasgow City, G1 5ED            G1 5ED
#
#   location.region
# 0    Glasgow City
# 1    Glasgow City
# 2    Glasgow City
# 3    Glasgow City
# 4    Glasgow City
# 5    Glasgow City

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
url2 = "https://api.foursquare.com/v3/places/search?query=restaurant%2C%20bar&fields=name%2Clocation%2Cgeocodes&near=glasgow&sort=RATING"


response2 = requests.get(url2, headers=headers)
response2.json()
x = response2.json()

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df3 = json_normalize(x['results'])
df3
# Out:
#                              name  geocodes.main.latitude  \
# 0               Alston Bar & Beef               55.860406
# 1  WEST Brewery, Bar & Restaurant               55.850907
# 2                   Tempo Tea Bar               55.859601
# 3            Riverhill Coffee Bar               55.860611
# 4             Max's Bar and Grill               55.859437
# 5                   The State Bar               55.865492
# 6  The Citizen Bar & Dining Rooms               55.861154
# 7           Tiki Bar & Kitsch Inn               55.864974
# 8                        Meat Bar               55.863630
# 9              Malone's Irish Bar               55.864532
#
#    geocodes.main.longitude  geocodes.roof.latitude  geocodes.roof.longitude  \
# 0                -4.257524               55.860406                -4.257524
# 1                -4.233765               55.850907                -4.233765
# 2                -4.252244               55.859601                -4.252244
# 3                -4.255778               55.860611                -4.255778
# 4                -4.252344               55.859437                -4.252344
# 5                -4.266265               55.865492                -4.266265
# 6                -4.252712               55.861154                -4.252712
# 7                -4.264251               55.864974                -4.264251
# 8                -4.260110               55.863630                -4.260110
# 9                -4.258140               55.864532                -4.258140
#
#                     location.address location.address_extended  \
# 0                       79 Gordon St                   Unit 19
# 1  Templeton Building, Glasgow Green                Building 4
# 2                        83 Queen St                       NaN
# 3                       24 Gordon St                       NaN
# 4                        73 Queen St                       NaN
# 5                148-148A Holland St                       NaN
# 6                   24 St Vincent Pl                       NaN
# 7                        214 Bath St                       NaN
# 8                 142 West Regent St                       NaN
# 9             57-59 Sauchiehall Lane                       NaN
#
#   location.admin_region location.country location.cross_street  \
# 0              Scotland               GB
# 1              Scotland               GB           1 The Green
# 2              Scotland               GB                   NaN
# 3              Scotland               GB
# 4              Scotland               GB                   NaN
# 5              Scotland               GB                   NaN
# 6              Scotland               GB
# 7              Scotland               GB                   NaN
# 8              Scotland               GB                   NaN
# 9              Scotland               GB
#
#                           location.formatted_address location.locality  \
# 0        79 Gordon St, Glasgow, Glasgow City, G1 3SQ           Glasgow
# 1  Templeton Building, Glasgow Green (1 The Green...           Glasgow
# 2         83 Queen St, Glasgow, Glasgow City, G1 3DA           Glasgow
# 3        24 Gordon St, Glasgow, Glasgow City, G1 3PU           Glasgow
# 4         73 Queen St, Glasgow, Glasgow City, G1 3BZ           Glasgow
# 5  148-148A Holland St, Glasgow, Glasgow City, G2...           Glasgow
# 6    24 St Vincent Pl, Glasgow, Glasgow City, G1 2EU           Glasgow
# 7         214 Bath St, Glasgow, Glasgow City, G2 4HW           Glasgow
# 8                142 West Regent St, Glasgow, G2 2RQ           Glasgow
# 9  57-59 Sauchiehall Lane, Glasgow, Glasgow City,...           Glasgow
#
#   location.post_town location.postcode location.region
# 0            Glasgow            G1 3SQ    Glasgow City
# 1            Glasgow           G40 1AW    Glasgow City
# 2            Glasgow            G1 3DA    Glasgow City
# 3            Glasgow            G1 3PU    Glasgow City
# 4            Glasgow            G1 3BZ    Glasgow City
# 5            Glasgow            G2 4NG    Glasgow City
# 6            Glasgow            G1 2EU    Glasgow City
# 7            Glasgow            G2 4HW    Glasgow City
# 8            Glasgow            G2 2RQ             NaN
# 9            Glasgow            G2 4AB    Glasgow City

# %%
df3= df3.drop(df3.columns[[3,4,5,6,7,8,9,11,12,13]], axis=1)
df3
# Out:
#                              name  geocodes.main.latitude  \
# 0               Alston Bar & Beef               55.860406
# 1  WEST Brewery, Bar & Restaurant               55.850907
# 2                   Tempo Tea Bar               55.859601
# 3            Riverhill Coffee Bar               55.860611
# 4             Max's Bar and Grill               55.859437
# 5                   The State Bar               55.865492
# 6  The Citizen Bar & Dining Rooms               55.861154
# 7           Tiki Bar & Kitsch Inn               55.864974
# 8                        Meat Bar               55.863630
# 9              Malone's Irish Bar               55.864532
#
#    geocodes.main.longitude                         location.formatted_address  \
# 0                -4.257524        79 Gordon St, Glasgow, Glasgow City, G1 3SQ
# 1                -4.233765  Templeton Building, Glasgow Green (1 The Green...
# 2                -4.252244         83 Queen St, Glasgow, Glasgow City, G1 3DA
# 3                -4.255778        24 Gordon St, Glasgow, Glasgow City, G1 3PU
# 4                -4.252344         73 Queen St, Glasgow, Glasgow City, G1 3BZ
# 5                -4.266265  148-148A Holland St, Glasgow, Glasgow City, G2...
# 6                -4.252712    24 St Vincent Pl, Glasgow, Glasgow City, G1 2EU
# 7                -4.264251         214 Bath St, Glasgow, Glasgow City, G2 4HW
# 8                -4.260110                142 West Regent St, Glasgow, G2 2RQ
# 9                -4.258140  57-59 Sauchiehall Lane, Glasgow, Glasgow City,...
#
#   location.region
# 0    Glasgow City
# 1    Glasgow City
# 2    Glasgow City
# 3    Glasgow City
# 4    Glasgow City
# 5    Glasgow City
# 6    Glasgow City
# 7    Glasgow City
# 8             NaN
# 9    Glasgow City

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
url3 = "https://api.yelp.com/v3/businesses/search?latitude=55.860406&longitude=-4.257524&term=bike&radius=1000"

headers3 = {
    "accept": "application/json",
    "Authorization": "Bearer kZgqMX-4XbV6TNT6mf-lGN0lZWpHbtBuQpQ8Kyq_ImHr52bvcx54PnPeR3-TinZo5ERO6AODMfzlFxZmFJ_jWkDO9f95PY47fPXzxMOqSWdSi3os2ldstRcaqPbaY3Yx"
}


response3= requests.get(url3, headers=headers3)
b = response3.json()
df4 = json_normalize(b['businesses'])
df4= df4.drop(df4.columns[[0,1,3,5,9,10]], axis=1)

# %%
df4= df4.drop(df4.columns[[1,3,5,6,10,11,12,14,15,16]], axis=1)
df4
# Out:
#                               name  review_count  rating     distance  \
# 0                     Evans Cycles             5     3.0   413.746554
# 1                         Nextbike             7     4.5   555.676587
# 2                     Dales Cycles            11     2.5   997.096547
# 3                    Sports Direct             7     2.5   510.219758
# 4            Billy Bilsland Cycles             3     4.5   973.263027
# 5  Tiso Glasgow Outdoor Experience            15     4.5  1114.812405
# 6       West Coast Harley Davidson             8     2.5   971.647179
# 7               5th Blocker Skates             3     5.0   384.226689
#
#    coordinates.latitude  coordinates.longitude location.city  \
# 0             55.863561              -4.254008       Glasgow
# 1             55.864237              -4.251806       Glasgow
# 2             55.867715              -4.248342       Glasgow
# 3             55.857970              -4.250447       Glasgow
# 4             55.854561              -4.246191       Glasgow
# 5             55.867313              -4.245250       Glasgow
# 6             55.864026              -4.271590       Glasgow
# 7             55.863403              -4.260588       Glasgow
#
#                             location.display_address
# 0   [19 Bath Street, Glasgow G2 1HY, United Kingdom]
# 1                          [Glasgow, United Kingdom]
# 2  [150 Dobbies Loan, Glasgow G4 0JE, United King...
# 3  [28-32 Argyle Street, Glasgow G2 8AD, United K...
# 4   [176 Saltmarket, Glasgow G1 5LA, United Kingdom]
# 5  [50 Couper Street, Glasgow G4 0DL, United King...
# 6  [147-151 North St, Glasgow G3 7DA, United King...
# 7  [143 W Regent Street, Glasgow G2 2SG, United K...

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
api_key = 'kZgqMX-4XbV6TNT6mf-lGN0lZWpHbtBuQpQ8Kyq_ImHr52bvcx54PnPeR3-TinZo5ERO6AODMfzlFxZmFJ_jWkDO9f95PY47fPXzxMOqSWdSi3os2ldstRcaqPbaY3Yx'

headers4 = {
    'accept': 'application/json',
    'Authorization': 'Bearer {}'.format(api_key)
    }
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'pub, restaurant, bar',
          'location': 'Glasgow, Scotland',
          'limit': 50}
response4 = requests.get(search_api_url, headers=headers4, params=params, timeout=5).json()
z = response4

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
data_dict = {

    'Lat' : [],
    'Long':[],
    'Review_Count':[],
    'Name' : [],
    'Rating' : [],
    'City' : []
}

for i in range(50):
  data_dict['Lat'].append(z['businesses'][i]['coordinates']['latitude']),
  data_dict['Long'].append(z['businesses'][i]['coordinates']['longitude']),
  data_dict['Review_Count'].append(z['businesses'][i]['review_count']),
  data_dict['Name'].append(z['businesses'][i]['name']),
  data_dict['Rating'].append(z['businesses'][i]['rating']),
  data_dict['City'].append(z['businesses'][i]['location']['city']),
  
df5 = pd.DataFrame.from_dict(data_dict,orient='columns')
df5
# Out:
#           Lat      Long  Review_Count                             Name  \
# 0   55.874915 -4.293247           152                  Ubiquitous Chip
# 1   55.864196 -4.260933           257        The Butterfly and the Pig
# 2   55.863588 -4.257858            32                  Rufus T Firefly
# 3   55.855316 -4.250300            27                       Scotia Bar
# 4   55.872544 -4.282411            98                       Stravaigin
# 5   55.860826 -4.256445            27                    Horseshoe Bar
# 6   55.865227 -4.285829            36                    The Ben Nevis
# 7   55.871283 -4.300637            44                The Sparkle Horse
# 8   55.877405 -4.289217           130                         Oran Mor
# 9   55.863866 -4.281028            18                 The Brass Monkey
# 10  55.865029 -4.265696            25                       Mini Grill
# 11  55.861441 -4.256623            48              The Drum and Monkey
# 12  55.864667 -4.256874            44                        Walkabout
# 13  55.864023 -4.281491            63                        Lebowskis
# 14  55.865734 -4.276900            47                         McPhabbs
# 15  55.860349 -4.259364             5                  The Smokin' Fox
# 16  55.858305 -4.244045            25                             Home
# 17  55.865850 -4.266039            18                        Bar Budda
# 18  55.859356 -4.248030            48                 BrewDog DogHouse
# 19  55.874027 -4.301817            38                        Cottier's
# 20  55.863281 -4.256176            53                        The Raven
# 21  55.860144 -4.233713            82               Drygate Brewing Co
# 22  55.875423 -4.293364            77                The Curler's Rest
# 23  55.865937 -4.269321            23                      Variety Bar
# 24  55.864538 -4.283614            29                          Distill
# 25  55.868347 -4.273617            35                        The Drake
# 26  55.862063 -4.253075            56                   Waxy O'Connors
# 27  55.872397 -4.272877            30                          Munro's
# 28  55.866643 -4.290341            57                         Firebird
# 29  55.937783 -4.212814             2                     Torrance Inn
# 30  55.863971 -4.259456            92                            Bloc+
# 31  55.865469 -4.266275            37                    THe State Bar
# 32  55.861125 -4.251693            91               The Counting House
# 33  55.858853 -4.248389            14  Citation Taverne and Restaurant
# 34  55.874950 -4.280763            51                         Inn Deep
# 35  55.858878 -4.245660            23                           Bar 91
# 36  55.874830 -4.292792            36                 Jinty McGuinty's
# 37  55.865512 -4.283756            26                      The Sisters
# 38  55.861107 -4.257999            99                           Stereo
# 39  55.857906 -4.244729            59                      Blackfriars
# 40  55.857478 -4.256287             9                     Times Square
# 41  55.866913 -4.259739            14          Jackson's Drink Mongers
# 42  55.858131 -4.223449            13                        Redmond's
# 43  55.874267 -4.276554            26      The Lansdowne Bar & Kitchen
# 44  55.859095 -4.248108            26                         Rab Ha's
# 45  55.854724 -4.234856            15   Saint Luke's And The Winged Ox
# 46  55.871839 -4.297911            34                        Bar Gumbo
# 47  55.859047 -4.248592            10                    The Steps Bar
# 48  55.859507 -4.248474            13                 Bacchus Cafe Bar
# 49  55.823493 -4.288082             8               Loks Bar & Kitchen
#
#     Rating     City
# 0      4.5  Glasgow
# 1      4.5  Glasgow
# 2      3.5  Glasgow
# 3      4.0  Glasgow
# 4      4.5  Glasgow
# 5      4.0  Glasgow
# 6      4.5  Glasgow
# 7      4.0  Glasgow
# 8      3.5  Glasgow
# 9      4.0  Glasgow
# 10     4.5  Glasgow
# 11     4.0  Glasgow
# 12     2.5  Glasgow
# 13     4.0  Glasgow
# 14     4.0  Glasgow
# 15     4.5  Glasgow
# 16     3.5  Glasgow
# 17     3.5  Glasgow
# 18     4.5  Glasgow
# 19     3.5  Glasgow
# 20     4.0  Glasgow
# 21     4.0  Glasgow
# 22     3.5  Glasgow
# 23     4.0  Glasgow
# 24     4.0  Glasgow
# 25     4.0  Glasgow
# 26     3.5  Glasgow
# 27     3.5  Glasgow
# 28     4.0  Glasgow
# 29     4.5  Glasgow
# 30     4.0  Glasgow
# 31     4.0  Glasgow
# 32     3.5  Glasgow
# 33     3.0  Glasgow
# 34     4.0  Glasgow
# 35     4.0  Glasgow
# 36     3.5  Glasgow
# 37     4.5  Glasgow
# 38     4.5  Glasgow
# 39     4.0  Glasgow
# 40     2.5  Glasgow
# 41     4.0  Glasgow
# 42     4.0  Glasgow
# 43     3.5  Glasgow
# 44     4.0  Glasgow
# 45     4.0  Glasgow
# 46     4.0  Glasgow
# 47     3.5  Glasgow
# 48     4.0  Glasgow
# 49     4.0  Glasgow

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Yelp API gave me a lot more information that was needed compared to Foursquare. Not sure if it was the city I chose, but Foursquare didn't have any column for rating or total number of ratings. Yelp was able to provide that information and it was very useful. Yelp also had a larger pool of results based on my queries, whereas Foursquare was very limited.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
df4.sort_values('rating', ascending=False).iloc[:10]
# Out:
#                               name  review_count  rating     distance  \
# 7               5th Blocker Skates             3     5.0   384.226689
# 1                         Nextbike             7     4.5   555.676587
# 4            Billy Bilsland Cycles             3     4.5   973.263027
# 5  Tiso Glasgow Outdoor Experience            15     4.5  1114.812405
# 0                     Evans Cycles             5     3.0   413.746554
# 2                     Dales Cycles            11     2.5   997.096547
# 3                    Sports Direct             7     2.5   510.219758
# 6       West Coast Harley Davidson             8     2.5   971.647179
#
#    coordinates.latitude  coordinates.longitude location.city  \
# 7             55.863403              -4.260588       Glasgow
# 1             55.864237              -4.251806       Glasgow
# 4             55.854561              -4.246191       Glasgow
# 5             55.867313              -4.245250       Glasgow
# 0             55.863561              -4.254008       Glasgow
# 2             55.867715              -4.248342       Glasgow
# 3             55.857970              -4.250447       Glasgow
# 6             55.864026              -4.271590       Glasgow
#
#                             location.display_address
# 7  [143 W Regent Street, Glasgow G2 2SG, United K...
# 1                          [Glasgow, United Kingdom]
# 4   [176 Saltmarket, Glasgow G1 5LA, United Kingdom]
# 5  [50 Couper Street, Glasgow G4 0DL, United King...
# 0   [19 Bath Street, Glasgow G2 1HY, United Kingdom]
# 2  [150 Dobbies Loan, Glasgow G4 0JE, United King...
# 3  [28-32 Argyle Street, Glasgow G2 8AD, United K...
# 6  [147-151 North St, Glasgow G3 7DA, United King...
