# %%
import os
import requests
import pandas as pd
import json
from pandas import json_normalize

# %%
url = 'http://api.citybik.es/v2/networks'

# %%
response = requests.get(url)

# %% [markdown]
# # CityBikes

# %%
params = {'fields': 'stations'}

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
glasgow = '/nextbike-glasgow'

# %%
response = requests.get(url + glasgow)

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
response = requests.get(url + glasgow, params=params)

# %%
y = response.json()

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
#create dataframe
df = json_normalize(y['network']['stations'])
df
# Out:
#      empty_slots  free_bikes                                id   latitude  \
# 0            4.0           7  af1d0f25cbc75377878349fde4d86133  55.858167
# 1            6.0           1  71b02b6f26f03e58c97dec1e1c9faa00  55.878278
# 2            3.0           1  fa6bc682e8627d66891c2b6250c81b1e  55.864788
# 3            1.0           0  a087989280fd941fd9c41c3e787940ae  55.862983
# 4            3.0           6  eb47a36e3d5fe5bc456397413bd2aa75  55.852500
# ..           ...         ...                               ...        ...
# 97           4.0           1  c8234c56f76f3f84d81c54ceedbdab54  55.859996
# 98           2.0           8  e7b590304d2ae958110e34961830ce68  55.846552
# 99           0.0           8  70c80c14fe5f7f1049a85e33856137ec  55.855961
# 100          4.0           1  d1cfef68e6b380467d3f8927379319b3  55.862973
# 101          8.0           0  12aac9e40a335ee43b231c94972a7a69  55.878152
#
#      longitude                               name  \
# 0    -4.245483         Merchant Square - ELECTRIC
# 1    -4.288487         Botanic Gardens - ELECTRIC
# 2    -4.271852                   Mitchell Library
# 3    -4.241000  University of Strathclyde (North)
# 4    -4.258850    Bridge Street Subway - ELECTRIC
# ..         ...                                ...
# 97   -4.270163          Anderston Railway Station
# 98   -4.332797                     Maryland Drive
# 99   -4.244671                           Trongate
# 100  -4.237745       Glasgow Cathedral - ELECTRIC
# 101  -4.242439                          St Rollox
#
#                        timestamp  \
# 0    2023-02-03T22:37:58.434000Z
# 1    2023-02-03T22:37:58.439000Z
# 2    2023-02-03T22:37:58.442000Z
# 3    2023-02-03T22:37:58.443000Z
# 4    2023-02-03T22:37:58.444000Z
# ..                           ...
# 97   2023-02-03T22:37:58.495000Z
# 98   2023-02-03T22:37:58.499000Z
# 99   2023-02-03T22:37:58.448000Z
# 100  2023-02-03T22:37:58.436000Z
# 101  2023-02-03T22:37:58.483000Z
#
#                                        extra.bike_uids extra.number  \
# 0    [47006, 81132, 47889, 46952, 46732, 46483, 46407]         8407
# 1                                              [47837]         8417
# 2                                              [46648]         8425
# 3                                                   []         8424
# 4           [81140, 47880, 47870, 46837, 46774, 46681]         8432
# ..                                                 ...          ...
# 97                                             [46982]         8312
# 98   [46913, 46844, 46831, 46830, 46757, 46461, 479...         8209
# 99   [47085, 46620, 46587, 46549, 46495, 46473, 479...         8431
# 100                                            [47144]         8409
# 101                                                 []         8236
#
#      extra.slots  extra.uid
# 0            8.0     264293
# 1            8.0     264302
# 2            6.0     264308
# 3            3.0     264309
# 4            5.0     264316
# ..           ...        ...
# 97           6.0  105741985
# 98          10.0  115737132
# 99           5.0     266169
# 100          6.0     264296
# 101          8.0   31234437
#
# [102 rows x 11 columns]

# %%
#delete coloumns that are not needed for project
df= df.drop(df.columns[[2,5,6,7,8,9,10]], axis=1)
df
# Out:
#      empty_slots  free_bikes   latitude  longitude
# 0            4.0           7  55.858167  -4.245483
# 1            6.0           1  55.878278  -4.288487
# 2            3.0           1  55.864788  -4.271852
# 3            1.0           0  55.862983  -4.241000
# 4            3.0           6  55.852500  -4.258850
# ..           ...         ...        ...        ...
# 97           4.0           1  55.859996  -4.270163
# 98           2.0           8  55.846552  -4.332797
# 99           0.0           8  55.855961  -4.244671
# 100          4.0           1  55.862973  -4.237745
# 101          8.0           0  55.878152  -4.242439
#
# [102 rows x 4 columns]
